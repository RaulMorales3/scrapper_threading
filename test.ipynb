# %%
from workers.wiki_worker import WikiWorker
from config import URL_COUNTRIES

worker = WikiWorker(url=URL_COUNTRIES)
companies = [company for company in worker.get_countries()]
companies[:10]
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria']

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://en.wikipedia.org/wiki/List_of_countries_by_birth_rate")
res.raise_for_status()
soup = BeautifulSoup(res.text, "html.parser")

# %%
table = soup.find("table")

# %%
rows = table.find_all("tr")
